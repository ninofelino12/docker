# %%
#COnnect To Odoo

# %%
import odoorpc

# Prepare the connection to the server
odoo = odoorpc.ODOO('localhost', port=8015)

# %%
#Select database

# %%
odoo.login('db_name', 'user', 'passwd')

# %%
user = odoo.env.user
print(user.name)            # name of the user connected
print(user.company_id.name) # the name of its company

# Simple 'raw' query
user_data = odoo.execute('res.users', 'read', [user.id])
print(user_data)
# Out:
# Mitchell Admin
# YourCompany
# [{'id': 2, 'partner_id': [3, 'YourCompany, Mitchell Admin'], 'login': 'user', 'password': '', 'new_password': '', 'signature': '<span data-o-mail-quote="1">-- <br data-o-mail-quote="1">Mitchell Admin</span>', 'active': True, 'active_partner': True, 'action_id': False, 'groups_id': [2, 11, 7, 16, 24, 26, 8, 1, 13, 19, 5, 3, 21, 6], 'log_ids': [3, 2], 'login_date': '2023-12-22 00:22:05', 'share': False, 'companies_count': 1, 'tz_offset': '+0700', 'company_id': [1, 'YourCompany'], 'company_ids': [1], 'name': 'Mitchell Admin', 'email': 'admin@yourcompany.example.com', 'accesses_count': 322, 'rules_count': 40, 'groups_count': 14, '__last_update': '2023-12-22 00:15:39', 'display_name': 'Mitchell Admin', 'create_uid': [1, 'OdooBot'], 'create_date': '2023-12-22 00:13:15', 'write_uid': [1, 'OdooBot'], 'write_date': '2023-12-22 00:15:39', 'api_key_ids': [], 'totp_enabled': False, 'totp_trusted_device_ids': [], 'im_status': 'online', 'resource_ids': [], 'resource_calendar_id': False, 'notification_type': 'email', 'res_users_settings_ids': [1], 'state': 'active', 'odoobot_state': 'disabled', 'odoobot_failed': False, 'message_is_follower': False, 'message_follower_ids': [], 'message_partner_ids': [], 'message_ids': [], 'has_message': False, 'message_unread': False, 'message_unread_counter': 0, 'message_needaction': False, 'message_needaction_counter': 0, 'message_has_error': False, 'message_has_error_counter': 0, 'message_attachment_count': 0, 'message_main_attachment_id': False, 'website_message_ids': [], 'message_has_sms_error': False, 'email_normalized': 'admin@yourcompany.example.com', 'is_blacklisted': False, 'message_bounce': 0, 'activity_ids': [], 'activity_state': False, 'activity_user_id': False, 'activity_type_id': False, 'activity_type_icon': False, 'activity_date_deadline': False, 'my_activity_date_deadline': False, 'activity_summary': False, 'activity_exception_decoration': False, 'activity_exception_icon': False, 'image_1920': '...', 'image_1024': '...', 'image_512': '...', 'image_256': '...', 'image_128': '...', 'avatar_1920': '...', 'avatar_1024': '...', 'avatar_512': '...', 'avatar_256': '...', 'avatar_128': '...', 'date': False, 'title': False, 'parent_id': False, 'parent_name': False, 'child_ids': [], 'ref': False, 'lang': 'en_US', 'active_lang_count': 1, 'tz': 'Asia/Jakarta', 'user_id': False, 'vat': False, 'same_vat_partner_id': False, 'bank_ids': [], 'website': False, 'comment': False, 'category_id': [], 'credit_limit': 0.0, 'employee': False, 'function': False, 'type': 'contact', 'street': '215 Vine St', 'street2': False, 'zip': '18503', 'city': 'Scranton', 'state_id': [47, 'Pennsylvania (US)'], 'country_id': [233, 'United States'], 'country_code': 'US', 'partner_latitude': 0.0, 'partner_longitude': 0.0, 'email_formatted': '"Mitchell Admin" <admin@yourcompany.example.com>', 'phone': '+1 555-555-5555', 'mobile': False, 'is_company': False, 'industry_id': False, 'company_type': 'person', 'color': 0, 'user_ids': [2], 'partner_share': False, 'contact_address': 'YourCompany\n215 Vine St\n\nScranton PA 18503\nUnited States', 'commercial_partner_id': [3, 'YourCompany, Mitchell Admin'], 'commercial_company_name': 'YourCompany', 'company_name': 'YourCompany', 'barcode': False, 'self': [3, 'YourCompany, Mitchell Admin'], 'channel_ids': [1], 'signup_token': False, 'signup_type': False, 'signup_expiration': False, 'signup_valid': False, 'signup_url': 'http://localhost:8015/web/login?db=db_name&login=user', 'property_product_pricelist': [1, 'Public Pricelist (USD)'], 'partner_gid': 0, 'additional_info': False, 'phone_sanitized': False, 'phone_sanitized_blacklisted': False, 'phone_blacklisted': False, 'mobile_blacklisted': False, 'phone_mobile_search': False, 'credit': 0.0, 'debit': 0.0, 'debit_limit': 0.0, 'total_invoiced': 0.0, 'currency_id': [2, 'USD'], 'journal_item_count': 0, 'property_account_payable_id': [14, '211000 Account Payable'], 'property_account_receivable_id': [6, '121000 Account Receivable'], 'property_account_pos ...

# %%
if 'sale.order' in odoo.env:
    Order = odoo.env['sale.order']
    order_ids = Order.search([])
    for order in Order.browse(order_ids):
        print(order.name)
        products = [line.product_id.name for line in order.order_line]
        print(products)

# %%
print(odoo.env['res.users']
     )
print(odoo.env.context)
# Out:
# Model('res.users')
# {'lang': 'en_US', 'tz': 'Asia/Jakarta', 'uid': 2}

# %%
Product = odoo.env['product.product']
isi=Product.name_get([3, 4])
print(isi)
# Out:
# [[3, 'Virtual Interior Design'], [4, 'Virtual Home Staging']]

# %%
odoo.config['auto_context'] = False
isi=Product.name_get([3, 4])    # Without context, lang 'en_US' by default
print(isi)
# Out:
# [[3, 'Virtual Interior Design'], [4, 'Virtual Home Staging']]

# %%
Module = odoo.env['ir.module.module']
module_id = Module.search([('name', '=', 'purchase')])
Module.button_immediate_install(module_id)
# Out:
# {'type': 'ir.actions.act_url', 'target': 'self', 'url': '/web'}
